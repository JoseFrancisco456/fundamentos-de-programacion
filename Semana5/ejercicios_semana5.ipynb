# %% [markdown]
# Tupla

# %%
numeros = (10, 20, 30, 40, 50)


frutas = ("manzana", "plátano", "cereza")


datos = ("Ana", 20, 1.65, True)


unico = (5,)

print(type(numeros)) 
print(len(numeros))
# Out:
# <class 'tuple'>
# 5

# %%
numeros = (10, 20, 30, 40, 50)

print(numeros[0])    
print(numeros[2])   
print(numeros[4])    
print(numeros[-1])  
print(numeros[-3])

# %%
numeros = (10, 20, 30, 40, 50)
numeros[1] = 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 numeros = (10, 20, 30, 40, 50)
# ----> 2 numeros[1] = 15
#
# TypeError: 'tuple' object does not support item assignment

# %%
coordenada = (2,6)
x , y = coordenada

print(f"coordenada en x: {x}")
print(f"coordenada en y: {y}")
# Out:
# coordenada en x: 2
# coordenada en y: 6

# %%
calificaciones = (88, 90 , 100 , 85)


calif5 = 50
calif6 = 80
nuevascalificaciones= calificaciones + (calif5 , calif6) 

print(calificaciones)
print(nuevascalificaciones)
# Out:
# (88, 90, 100, 85)
# (88, 90, 100, 85, 50, 80)

# %%
desordenada = (9,2,7,10,0,8,14,22,4)

print(type(desordenada))
print(desordenada)
lista = list(desordenada)
print(type(lista))
print(lista)
lista.sort()
print(lista)
ordenada = tuple(lista)
print(type(ordenada))
print(ordenada)
# Out:
# <class 'tuple'>
# (9, 2, 7, 10, 0, 8, 14, 22, 4)
# <class 'list'>
# [9, 2, 7, 10, 0, 8, 14, 22, 4]
# [0, 2, 4, 7, 8, 9, 10, 14, 22]
# <class 'tuple'>
# (0, 2, 4, 7, 8, 9, 10, 14, 22)

# %%
def suma_tupla(t):
    total = 0
    for e in t:
        total += e
    return total
calorias = (800, 950 , 700 , 1300 , 800 , 900 , 650)

resultado = suma_tupla(calorias)

print(f"Metiste a tu cuerpo {resultado} calorias ,gordo ")
# Out:
# Metiste a tu cuerpo 6100 calorias ,gordo

# %% [markdown]
# Diccionarios

# %%
contactos = {
    "Ricardo": "555-0101",
    "Luis": "555-0102",
    "Mía": "555-0103"
}
print(type(contactos))
print(len(contactos))
# Out:
# <class 'dict'>
# 3

# %%
contactos = {
    "Ricardo": "555-0101",
    "Luis": "555-0102",
    "Mía": "555-0103"
}
print(contactos ["Luis"])
print(contactos.get ("Raul"))
print(contactos.get ("Raul" , " Si registro"))
# Out:
# 555-0102
# None
#  Si registro

# %%
contactos = {
    "Ricardo": "555-0101",
    "Luis": "555-0102",
    "Mía": "555-0103"
}
contactos ["Cris"] = "28838819"
contactos ["Ricardo"] = "3344551"


print(contactos)
# Out:
# {'Ricardo': '3344551', 'Luis': '555-0102', 'Mía': '555-0103', 'Cris': '28838819'}

# %%
print(contactos.keys())
print(contactos.values())
print(contactos.items())
# Out:
# dict_keys(['Ricardo', 'Luis', 'Mía', 'Cris'])
# dict_values(['3344551', '555-0102', '555-0103', '28838819'])
# dict_items([('Ricardo', '3344551'), ('Luis', '555-0102'), ('Mía', '555-0103'), ('Cris', '28838819')])

# %%
print("\nImpresion de llaves ")
for n in contactos.keys():
    print(n)

print("\nImpresion de valores ")
for v in contactos.values():
    print(v)

print("\nImpresion de completa ")
for n , t in contactos.items():
    print(f"Nombre: {n} , Telefono {t}")
# Out:
# Impresion de llaves
# Ricardo
# Luis
# Mía
# Cris
#
# Impresion de valores
# 3344551
# 555-0102
# 555-0103
# 28838819
#
# Impresion de completa
# Nombre: Ricardo , Telefono 3344551
# Nombre: Luis , Telefono 555-0102
# Nombre: Mía , Telefono 555-0103
# Nombre: Cris , Telefono 28838819

# %%
def buscar_telefono(contactos, nombre):
    return contactos.get(nombre, "Contacto no encontrado")
nombre = input (" Escribe el nombre del contacto que buscas")
telefono = buscar_telefono( contactos , nombre)
print(f"EL telefono de {nombre} es: {telefono}")
# Out:
# EL telefono de Luis es: 555-0102

# %% [markdown]
# ## Excepciones

# %%
try:
    edad = int(input("Ingresa tu edad: "))
    print("Tu edad es:", edad)
except ValueError:
    print("Error: Debes ingresar solo números enteros.")
# Out:
# Error: Debes ingresar solo números enteros.

# %%
try:
    dividendo = int (input("Dame un numero: "))
    divisor = int(input("Entre que numero lo dividimos:"))
    resultado = dividendo / divisor
    
except ZeroDivisionError:
    print( "Error de division entre cero")
else:
    print(f"El resultado es {resultado}")
finally:
    print("Fue un gusto hacer la division , chido")
# Out:
# Error de division entre cero
# Fue un gusto hacer la division , chido

# %%
for n , t in contactos.items():
    print(f"Nombre: {n} , Telefono {t}")
# Out:
# Nombre: Ricardo , Telefono 3344551
# Nombre: Luis , Telefono 555-0102
# Nombre: Mía , Telefono 555-0103
# Nombre: Cris , Telefono 28838819

# %%
def buscar_telefono(contactos, nombre):
    return contactos.get(nombre, "Contacto no encontrado")
nombre = input (" Escribe el nombre del contacto que buscas")
telefono = buscar_telefono( contactos , nombre)
print(f"EL telefono de {nombre} es: {telefono}")

# %%
nombre = "ricardo"

print(nombre.upper())
print(nombre.lower())
print(nombre.capitalize())
# Out:
# RICARDO
# ricardo

# %% [markdown]
# Ejercicios

# %%
candidatos = {
    "A": 0,
    "B": 0,
    "C": 0
}
cantidad = int (input ("¿Cuantos Votos van a ser?"))
conteo = 1
while conteo <= cantidad:
    voto = input (f"Ingresa el voto {conteo} (A , B o C): ")
    if voto.upper() in candidatos:
        print(f"Votos {conteo}")
        print(f"Voto para {voto.upper()}")
        candidatos[voto.upper()]+= 1
        conteo=+1
    else:
        print("EL voto no es valido")
   

for k , v in candidatos.items():
    print(f"Opcion {k} , votos: {v}")
# Out:
# EL voto no es valido
# Votos 1
# Voto para A
# Votos 1
# Voto para A
# Votos 1
# Voto para B
# Votos 1
# Voto para C
# EL voto no es valido
# Votos 1
# Voto para A
# Votos 1
# Voto para C
# EL voto no es valido
# EL voto no es valido
# EL voto no es valido
# EL voto no es valido

# %%
colores = ("rojo", "verde", "azul", "amarillo", "naranja")
print (colores)
print("el tercer color es : ",colores[2])
print("el primer color es : ",colores[0])
# Out:
# ('rojo', 'verde', 'azul', 'amarillo', 'naranja')
# el tercer color es :  azul
# el primer color es :  rojo

# %%
frutas = ("manzana", "plátano", "cereza", "durazno")
print( "La tupla tiene :",len(frutas) , "elementos")
# Out:
# La tupla tiene : 4 elementos

# %%
puntos = (5, 10, 15, 20, 25, 30)

print("El ultimo elemento es: ", puntos[-1])
print("El tercero desde el final es : ", puntos[-3])
# Out:
# El ultimo elemento es:  30
# El tercero desde el final es :  20

# %%
puntos = (5, 10, 15)
puntos[0] = 99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 puntos = (5, 10, 15)
# ----> 2 puntos[0] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %%
a, b, c = (7, 8, 9)
print("a= ",a)
print("b= ",b)
print("c= ",c)
# Out:
# a=  7
# b=  8
# c=  9

# %%
t1= (1,2,3)
t2= (4,5)
t3= t1 + t2
print("La nueva tupla es: ", t3)
# Out:
# La nueva tupla es:  (1, 2, 3, 4, 5)

# %%
numeros = (10, 20, 30)
otros_numeros = (40,50)
nuevos_numeros= numeros + otros_numeros

print("Nueva tupla: ", nuevos_numeros)
# Out:
# Nueva tupla:  (10, 20, 30, 40, 50)

# %%
desorden = (8, 3, 12, 5, 1)
lista = list(desorden)
lista.sort() 
print("ordenada:", lista)
# Out:
# ordenada: [1, 3, 5, 8, 12]

# %%
def suma_tupla(t):
    total = 0
    for n in t:
        total += n
    return total

numeros = (2,4,6,8)
resultado = suma_tupla(numeros)
print("La suma de la tupla es:", resultado)
